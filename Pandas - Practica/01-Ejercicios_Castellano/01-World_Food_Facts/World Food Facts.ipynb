# %% [markdown]
# # Ex1 - Obtener y conocer sus datos

# %% [markdown]
# ### Paso 1: Ir a https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Paso 2. Descargue el conjunto de datos en su ordenador y descomprímalo.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Paso 3. Utilice el archivo csv y asígnelo a un marco de datos llamado alimentos

# %%
food = pd.read_csv('C:/Users/helen/OneDrive/Documentos/GitHub/Core/Pandas - Practica/01-Ejercicios_Castellano/01-World_Food_Facts/food_100.csv')

# %% [markdown]
# ### Paso 4. Ver las 5 primeras entradas

# %%
food.head(20)
# Out:
#     Unnamed: 0   code                                                url  \
# 0            0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1            1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2            2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3            3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4            4  16094  http://world-en.openfoodfacts.org/product/0000...
# 5            5  16100  http://world-en.openfoodfacts.org/product/0000...
# 6            6  16117  http://world-en.openfoodfacts.org/product/0000...
# 7            7  16124  http://world-en.openfoodfacts.org/product/0000...
# 8            8  16193  http://world-en.openfoodfacts.org/product/0000...
# 9            9  16513  http://world-en.openfoodfacts.org/product/0000...
# 10          10  16612  http://world-en.openfoodfacts.org/product/0000...
# 11          11  16650  http://world-en.openfoodfacts.org/product/0000...
# ...

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 164 entries, Unnamed: 0 to water-hardness_100g
# dtypes: float64(125), int64(4), object(35)
# memory usage: 128.3+ KB

# %% [markdown]
# ### Paso 5. ¿Cuál es el número de observaciones del conjunto de datos?

# %%
food.describe()
# Out:
#        Unnamed: 0         code     created_t  last_modified_t  generic_name  \
# count  100.000000    100.00000  1.000000e+02     1.000000e+02           0.0
# mean    49.500000  25243.92000  1.488157e+09     1.488157e+09           NaN
# std     29.011492   8257.77455  6.895563e+06     6.895160e+06           NaN
# min      0.000000   3087.00000  1.434531e+09     1.434536e+09           NaN
# 25%     24.750000  18367.50000  1.489056e+09     1.489056e+09           NaN
# 50%     49.500000  28621.50000  1.489056e+09     1.489056e+09           NaN
# 75%     74.250000  33326.75000  1.489056e+09     1.489056e+09           NaN
# max     99.000000  35170.00000  1.502444e+09     1.502444e+09           NaN
#
#        origins  origins_tags  manufacturing_places  manufacturing_places_tags  \
# count      0.0           0.0                   0.0                        0.0
# mean       NaN           NaN                   NaN                        NaN
# ...

# %% [markdown]
# ### Paso 6. ¿Cuál es el número de columnas del conjunto de datos?

# %%
len(food.columns)
# Out:
# 164

# %% [markdown]
# ### Paso 7. Imprime el nombre de todas las columnas.

# %%
food.columns
# Out:
# Index(['Unnamed: 0', 'code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=164)

# %% [markdown]
# ### Paso 8. ¿Cómo se llama la columna 105?

# %%
food.columns[105]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Paso 9. ¿Cuál es el tipo de las observaciones de la columna 105?

# %%
food['-glucose_100g'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Paso 10. ¿Cómo se indexa el conjunto de datos?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %% [markdown]
# ### Paso 11. ¿Cuál es el nombre del producto de la 19ª observación?

# %%
food['product_name'][19]
# Out:
# 'Organic Oat Groats'
